# %%
import Get_Data as g
# Out:
# /anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
cat_data = g.Get_Category_Data()
# Out:
# /Users/rcheer/Desktop/Galvanize/Capstone/Fantasy-Basketball-Capstone-Project/src/Get_Data.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   points[i]=pd.to_numeric(points[i])
# /Users/rcheer/Desktop/Galvanize/Capstone/Fantasy-Basketball-Capstone-Project/src/Get_Data.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   rebounds[i]=pd.to_numeric(rebounds[i])
# /Users/rcheer/Desktop/Galvanize/Capstone/Fantasy-Basketball-Capstone-Project/src/Get_Data.py:52: SettingWithCopyWarning:
# ...

# %%
cat_data.get_train_test_split()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-dfd2e3be5365> in <module>()
# ----> 1 cat_data.get_train_test_split()
#
# ~/Desktop/Galvanize/Capstone/Fantasy-Basketball-Capstone-Project/src/Get_Data.py in get_train_test_split(self, test_proportion)
#     159         self.X_train_FTM,self.X_test_FTM,self.y_train_FTM,self.y_test_FTM = train_test_split(self.X_FTM,self.y_FTM,test_size = 0.3)
#     160
# --> 161         self.X_FGP = self.percentages[(self.percentages['season']!=2017) & (self.percentages['Games']>30)][['FG_percent_ly','career_FGpercent','age','age_squared','yearspro','yearspro_squared','max_teammateto','max_teammateshot_attempts','max_teammate_usage','max_teammatepts','usagerank']]
#     162         self.y_FGP = self.percentages[(self.percentages['season']!=2017) & (self.percentages['Games']>30)]['FG_percent']
# ...

# %%
cat_data.X_train_assists
# Out:
#       season  age  assists_ly  change_assists_ly  C_PF  PG  SG_SF  \
# 774     2014   32         0.5                0.1     1   0      0
# 1609    2012   23         0.9                0.3     1   0      0
# 1546    2012   27         1.5               -1.5     0   0      1
# 2002    2011   31         0.5                0.0     0   0      1
# 1579    2010   29         6.5               -1.0     0   0      1
# 761     2016   24         1.2                0.4     0   0      1
# 1432    2016   26         3.3               -0.3     1   0      0
# 2732    2010   33         4.9                1.3     0   0      1
# 1765    2012   27         0.8               -0.4     1   0      0
# 1804    2014   24         0.0               -0.4     1   0      0
# 937     2011   28         2.1               -0.6     0   0      1
# 3616    2016   24         1.0               -0.8     0   0      1
# 3532    2015   22         0.9                0.4     1   0      0
# ...
