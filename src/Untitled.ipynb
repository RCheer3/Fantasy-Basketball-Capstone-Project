# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.basketball-reference.com/players/j/jamesle01/gamelog/2017'
test = requests.get(url).text

# %%
soup = BeautifulSoup(test,'html.parser')

# %%
a = soup.findAll('td','left')

# %%
a
# Out:
# [<td class="left"><tr><td>20-29</td><td>6</td></tr>
#  <tr><td>30-39</td><td>49</td></tr>
#  <tr><td>40+</td><td>19</td></tr>
#  </td>, <td class="left"><tr><td>10-19</td><td>13</td></tr>
#  <tr><td>20-29</td><td>38</td></tr>
#  <tr><td>30-39</td><td>21</td></tr>
#  <tr><td>40-49</td><td>2</td></tr>
#  </td>, <td class="left"><tr><td> 0-4</td><td>4</td></tr>
#  <tr><td> 5-9</td><td>44</td></tr>
#  <tr><td>10-14</td><td>24</td></tr>
#  <tr><td>15-19</td><td>2</td></tr>
#  </td>, <td class="left"><tr><td> 0-4</td><td>7</td></tr>
#  <tr><td> 5-9</td><td>38</td></tr>
#  <tr><td>10-14</td><td>24</td></tr>
#  <tr><td>15-19</td><td>5</td></tr>
#  </td>, <td class="left"><tr><td>0</td><td>19</td></tr>
#  <tr><td>1-2</td><td>47</td></tr>
#  <tr><td>3-4</td><td>8</td></tr>
#  </td>, <td class="left"><tr><td>0</td><td>42</td></tr>
#  <tr><td>1-2</td><td>30</td></tr>
#  <tr><td>3-4</td><td>2</td></tr>
#  </td>, <td class="left"><tr><td>0</td><td>11</td></tr>
#  <tr><td>1-2</td><td>46</td></tr>
# ...

# %%
first.table
# Out:
# <table class="row_summable sortable stats_table" data-cols-to-freeze="3" id="pgl_basic"><caption>2016-17 Regular Season Table</caption>
# <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup>
# <thead>
# <tr>
# <th aria-label="Rank" class="ranker poptip sort_default_asc show_partial_when_sorting center" data-stat="ranker" data-tip="Rank" scope="col">Rk</th>
# <th aria-label="Season Game" class=" poptip center" data-stat="game_season" data-tip="Season Game" scope="col">G</th>
# <th aria-label="Date" class=" poptip sort_default_asc center" data-stat="date_game" scope="col">Date</th>
# <th aria-label="Age of Player at the start of February 1st of that season." class=" poptip sort_default_asc center" data-stat="age" data-tip="Age of Player at the start of February 1st of that season." scope="col">Age</th>
# ...

# %%
def speak(self):
    return "ook ook eee eee eee!"
cat_data.speak = speak

# %%
a = Player_ranker()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-9331be5a0130> in <module>()
# ----> 1 a = Player_ranker()
#
# TypeError: __init__() missing 1 required positional argument: 'playerdata'

# %%
from Get_Data import Get_Category_Data
cat_data = Get_Category_Data(test_year=2017)

def speak(self):
    return "ook ook eee eee eee!"
cat_data.speak = speak
# Out:
# /anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)
# /Users/rcheer/Desktop/Galvanize/Capstone/Fantasy-Basketball-Capstone-Project/src/Get_Data.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   points[i]=pd.to_numeric(points[i])
# /Users/rcheer/Desktop/Galvanize/Capstone/Fantasy-Basketball-Capstone-Project/src/Get_Data.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
def speak(self):
    return "ook ook eee eee eee!"
cat_data.speak = speak

# %%
cat_data.speak('a')
# Out:
# 'ook ook eee eee eee!'

# %%
sentence = 'This is a sentence'
dict_ = {}
for i in sentence.lower():
    if i in dict_:
        dict_[i]+=1
    else:
        dict_[i]=1
dict_
# Out:
# {'t': 2, 'h': 1, 'i': 2, 's': 3, ' ': 3, 'a': 1, 'e': 3, 'n': 2, 'c': 1}
